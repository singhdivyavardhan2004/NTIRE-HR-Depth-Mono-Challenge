# %%
# !git clone https://github.com/liamaltarac/NTIRE-Stereo-Depth_2025.git
# %cd NTIRE-Stereo-Depth_2025
# Out:
# Cloning into 'NTIRE-Stereo-Depth_2025'...
# remote: Enumerating objects: 1184, done.
# remote: Counting objects: 100% (297/297), done.
# remote: Compressing objects: 100% (232/232), done.
# remote: Total 1184 (delta 71), reused 268 (delta 57), pack-reused 887 (from 1)
# Receiving objects: 100% (1184/1184), 66.44 MiB | 23.99 MiB/s, done.
# Resolving deltas: 100% (207/207), done.
# /content/NTIRE-Stereo-Depth_2025

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 948.0/948.0 kB 29.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.7/180.7 kB 20.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 150.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 kB 15.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.7/76.7 kB 8.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.8/59.8 kB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 788.2/788.2 kB 59.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 97.5 MB/s eta 0:00:00
# ...

# %%
# !mkdir -p checkpoints_new

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-8b4fea6d-7040-494b-ae90-8cb1e8cc1458" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8b4fea6d-7040-494b-ae90-8cb1e8cc1458">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mv *.pth checkpoints_new/
